# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib .pyplot as plt
import seaborn as sns

# %%
foods = pd.Series(['Almond butter', 'Eggs', 'Avocado'])
price = pd.Series([9, 6, 2])
food_data = pd.DataFrame({'food' : foods,
                         'prices' : price})
food_data
# Out:
#             food  prices
# 0  Almond butter       9
# 1           Eggs       6
# 2        Avocado       2

# %%
df = pd.read_csv('car-sales.csv')
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df.shape
# Out:
# (10, 5)

# %%
df.isnull().sum()
# Out:
# Make             0
# Colour           0
# Odometer (KM)    0
# Doors            0
# Price            0
# dtype: int64

# %%
df.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
df.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
df.mean()
# Out:
# C:\Users\240g_W10\AppData\Local\Temp\ipykernel_6040\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
len(df)
# Out:
# 10

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
df.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
df['Odometer (KM)']
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
df['Odometer (KM)'].mean()
# Out:
# 78601.4

# %%
df[df['Odometer (KM)'] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
df['Doors'].value_counts()
# Out:
# 4    8
# 3    1
# 5    1
# Name: Doors, dtype: int64

# %%
pd.crosstab(df['Make'], df['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
df.groupby(['Make']).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
df['Odometer (KM)'].plot()
# Out:
# <AxesSubplot:>

# %%
df['Odometer (KM)'].hist()
# Out:
# <AxesSubplot:>

# %%
df['Price'].value_counts()
# Out:
# $7,000.00     2
# $4,000.00     1
# $5,000.00     1
# $22,000.00    1
# $3,500.00     1
# $4,500.00     1
# $7,500.00     1
# $6,250.00     1
# $9,700.00     1
# Name: Price, dtype: int64

# %%
df['Price'] = df['Price'].str.replace("[\$\,\.]", "")
# Out:
# C:\Users\240g_W10\AppData\Local\Temp\ipykernel_6040\273254110.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Price'] = df['Price'].str.replace("[\$\,\.]", "")

# %%
df['Price']
# Out:
# 0     400000
# 1     500000
# 2     700000
# 3    2200000
# 4     350000
# 5     450000
# 6     750000
# 7     700000
# 8     625000
# 9     970000
# Name: Price, dtype: object

# %%
df['Price'] = df['Price'].str[:-2]

# %%
df['Price']
# Out:
# 0     4000
# 1     5000
# 2     7000
# 3    22000
# 4     3500
# 5     4500
# 6     7500
# 7     7000
# 8     6250
# 9     9700
# Name: Price, dtype: object

# %%
df['Price'] = df['Price'].astype(float)

# %%
df['Price']
# Out:
# 0     4000.0
# 1     5000.0
# 2     7000.0
# 3    22000.0
# 4     3500.0
# 5     4500.0
# 6     7500.0
# 7     7000.0
# 8     6250.0
# 9     9700.0
# Name: Price, dtype: float64

# %%
df['Price'] = df['Price'].astype(int)

# %%
df['Price']
# Out:
# 0     4000
# 1     5000
# 2     7000
# 3    22000
# 4     3500
# 5     4500
# 6     7500
# 7     7000
# 8     6250
# 9     9700
# Name: Price, dtype: int32

# %%
df['Make'] = df['Make'].str.lower()
df
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
car_sales_missing = pd.read_csv('car-sales-missing-data.csv')
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean(), inplace = True)
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna( inplace = True)
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
df['Seats'] =5
df
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  toyota  White         150043      4   4000      5
# 1   honda    Red          87899      4   5000      5
# 2  toyota   Blue          32549      3   7000      5
# 3     bmw  Black          11179      5  22000      5
# 4  nissan  White         213095      4   3500      5
# 5  toyota  Green          99213      4   4500      5
# 6   honda   Blue          45698      4   7500      5
# 7   honda   Blue          54738      4   7000      5
# 8  toyota  White          60000      4   6250      5
# 9  nissan  White          31600      4   9700      5

# %%
engine_sizes = [1.3, 4.3, 2.3, 3.3, 3.0, 2.3, 1.4, 1.7, 2.5, 3.1]
df['Engine size'] = engine_sizes
df
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Engine size
# 0  toyota  White         150043      4   4000      5          1.3
# 1   honda    Red          87899      4   5000      5          4.3
# 2  toyota   Blue          32549      3   7000      5          2.3
# 3     bmw  Black          11179      5  22000      5          3.3
# 4  nissan  White         213095      4   3500      5          3.0
# 5  toyota  Green          99213      4   4500      5          2.3
# 6   honda   Blue          45698      4   7500      5          1.4
# 7   honda   Blue          54738      4   7000      5          1.7
# 8  toyota  White          60000      4   6250      5          2.5
# 9  nissan  White          31600      4   9700      5          3.1

# %%
df['price Per KM'] = df['Price'] / df['Odometer (KM)']
df
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Engine size  \
# 0  toyota  White         150043      4   4000      5          1.3
# 1   honda    Red          87899      4   5000      5          4.3
# 2  toyota   Blue          32549      3   7000      5          2.3
# 3     bmw  Black          11179      5  22000      5          3.3
# 4  nissan  White         213095      4   3500      5          3.0
# 5  toyota  Green          99213      4   4500      5          2.3
# 6   honda   Blue          45698      4   7500      5          1.4
# 7   honda   Blue          54738      4   7000      5          1.7
# 8  toyota  White          60000      4   6250      5          2.5
# 9  nissan  White          31600      4   9700      5          3.1
#
#    price Per KM
# 0      0.026659
# 1      0.056883
# 2      0.215060
# 3      1.967976
# 4      0.016425
# 5      0.045357
# 6      0.164121
# 7      0.127882
# 8      0.104167
# 9      0.306962

# %%
df = df.drop('price Per KM', axis=1)
df
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Engine size
# 0  toyota  White         150043      4   4000      5          1.3
# 1   honda    Red          87899      4   5000      5          4.3
# 2  toyota   Blue          32549      3   7000      5          2.3
# 3     bmw  Black          11179      5  22000      5          3.3
# 4  nissan  White         213095      4   3500      5          3.0
# 5  toyota  Green          99213      4   4500      5          2.3
# 6   honda   Blue          45698      4   7500      5          1.4
# 7   honda   Blue          54738      4   7000      5          1.7
# 8  toyota  White          60000      4   6250      5          2.5
# 9  nissan  White          31600      4   9700      5          3.1

# %%
df['Odometer (KM)'] = df['Odometer (KM)'].apply(lambda x : x/1.6)
df
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Engine size
# 0  toyota  White      93776.875      4   4000      5          1.3
# 1   honda    Red      54936.875      4   5000      5          4.3
# 2  toyota   Blue      20343.125      3   7000      5          2.3
# 3     bmw  Black       6986.875      5  22000      5          3.3
# 4  nissan  White     133184.375      4   3500      5          3.0
# 5  toyota  Green      62008.125      4   4500      5          2.3
# 6   honda   Blue      28561.250      4   7500      5          1.4
# 7   honda   Blue      34211.250      4   7000      5          1.7
# 8  toyota  White      37500.000      4   6250      5          2.5
# 9  nissan  White      19750.000      4   9700      5          3.1

# %%
df = df.rename(columns = {'Odometer (KM)' : 'Odometer (Miles)'})
df
# Out:
#      Make Colour  Odometer (Miles)  Doors  Price  Seats  Engine size
# 0  toyota  White         93776.875      4   4000      5          1.3
# 1   honda    Red         54936.875      4   5000      5          4.3
# 2  toyota   Blue         20343.125      3   7000      5          2.3
# 3     bmw  Black          6986.875      5  22000      5          3.3
# 4  nissan  White        133184.375      4   3500      5          3.0
# 5  toyota  Green         62008.125      4   4500      5          2.3
# 6   honda   Blue         28561.250      4   7500      5          1.4
# 7   honda   Blue         34211.250      4   7000      5          1.7
# 8  toyota  White         37500.000      4   6250      5          2.5
# 9  nissan  White         19750.000      4   9700      5          3.1
